# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="database-3.c71vmslgnnmk.us-east-1.rds.amazonaws.com",
  user="admin",
  password="senai115"
)

print(mydb)

# %%
mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="database-3.c71vmslgnnmk.us-east-1.rds.amazonaws.com",
  user="admin",
  password="senai115"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE DATABASE tabela_exercicio")

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="database-3.c71vmslgnnmk.us-east-1.rds.amazonaws.com",
  user="admin",
  password="senai115",
  database="tabela_exercicio"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE tabela_do_exercicio (numeros VARCHAR(255))")

# %%
mycursor = mydb.cursor()


mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
# ('tabela_exercicio',)

# %%
from os import cpu_count
mycursor = mydb.cursor()

sql = "INSERT INTO tabela_do_exercicio (numeros) VALUES (%s)"
uso_cpu = [
[20, 25, 40, 50, 45, 60, 55, 35, 70, 65],
[30, 35, 50, 60, 40, 55, 60, 45, 50, 55],
[15, 20, 30, 25, 35, 40, 45, 50, 55, 60],
[10, 15, 25, 35, 45, 50, 55, 60, 65, 70],
]

# for para adicionar cada elemento da uso_cpu
for i in uso_cpu:
    for value in i:
        mycursor.execute(sql, (value,))

mydb.commit()

print(mycursor.rowcount, "registros inseridos.")
# Out:
# 1 registros inseridos.

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="database-3.c71vmslgnnmk.us-east-1.rds.amazonaws.com",
  user="admin",
  password="senai115",
  database="tabela_exercicio"
)

mycursor = mydb.cursor()

mycursor.execute("SELECT * FROM tabela_do_exercicio ")

myresult = mycursor.fetchall()

for x in myresult:
  print(x)
# Out:
# ('20',)
# ('25',)
# ('40',)
# ('50',)
# ('45',)
# ('60',)
# ('55',)
# ('35',)
# ('70',)
# ('65',)
# ('30',)
# ('35',)
# ('50',)
# ('60',)
# ('40',)
# ('55',)
# ('60',)
# ('45',)
# ('50',)
# ('55',)
# ('15',)
# ('20',)
# ('30',)
# ('25',)
# ('35',)
# ('40',)
# ('45',)
# ('50',)
# ('55',)
# ('60',)
# ('10',)
# ('15',)
# ('25',)
# ('35',)
# ('45',)
# ('50',)
# ('55',)
# ('60',)
# ('65',)
# ('70',)
