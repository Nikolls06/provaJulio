# %%
uso_cpu = [
[20, 25, 40, 50, 45, 60, 55, 35, 70, 65],
[30, 35, 50, 60, 40, 55, 60, 45, 50, 55],
[15, 20, 30, 25, 35, 40, 45, 50, 55, 60],
[10, 15, 25, 35, 45, 50, 55, 60, 65, 70],
]

# %%
import pandas as pd

# %%
df = pd.DataFrame(uso_cpu)

df.columns = ['1h', '2h', '3h', '4h', '5h', '6h', '7h', '8h', '9h', '10h']

df
# Out:
#    1h  2h  3h  4h  5h  6h  7h  8h  9h  10h
# 0  20  25  40  50  45  60  55  35  70   65
# 1  30  35  50  60  40  55  60  45  50   55
# 2  15  20  30  25  35  40  45  50  55   60
# 3  10  15  25  35  45  50  55  60  65   70

# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.9/33.9 MB 30.4 MB/s eta 0:00:00
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-26-1c4a20edd000> in <cell line: 0>()
#       1 import mysql.connector
#       2
# ----> 3 mydb = mysql.connector.connect(
#       4   host="database-3.c71vmslgnnmk.us-east-1.rds.amazonaws.com",
#       5   user="admin",
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     321     if CMySQLConnection and not use_pure:
#     322         return CMySQLConnection(*args, **kwargs)
# --> 323     return MySQLConnection(*args, **kwargs)
#     324
#     325
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/connection.py in __init__(self, **kwargs)
#     183         if kwargs:
#     184             try:
# --> 185                 self.connect(**kwargs)
#     186             except Exception:
#     187                 # Tidy-up underlying socket on failure
#
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="database-3.c71vmslgnnmk.us-east-1.rds.amazonaws.com",
  user="admin",
  password="senai115",
  database="database-3"
)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE tabela (Nome VARCHAR(255), Endereco VARCHAR(255))")

mycursor.execute("SHOW COLUMNS FROM tabela")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-24-3887d708dcce> in <cell line: 0>()
#       1 import mysql.connector
#       2
# ----> 3 mydb = mysql.connector.connect(
#       4   host="database-3.c71vmslgnnmk.us-east-1.rds.amazonaws.com",
#       5   user="admin",
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     321     if CMySQLConnection and not use_pure:
#     322         return CMySQLConnection(*args, **kwargs)
# --> 323     return MySQLConnection(*args, **kwargs)
#     324
#     325
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/connection.py in __init__(self, **kwargs)
#     183         if kwargs:
#     184             try:
# --> 185                 self.connect(**kwargs)
#     186             except Exception:
#     187                 # Tidy-up underlying socket on failure
#
# ...
